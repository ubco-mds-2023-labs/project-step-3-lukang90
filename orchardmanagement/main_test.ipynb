# %%
import os
import sys
#current_directory = os.path.abspath(os.getcwd())

# %%
# %run main.py
# Out:
# Welcome to the Orchard Management Software, where you can easily manage your orchard, record harvests, and create a fruitful orchard experience!
#                         Ambrosia apple Elberta peach Lapins cherry
# pick_area                            0             0            40
# picking_regions_index             None          None             3
# market_area                         20            30             0
# marketing_regions_index              1             2          None
# The product of Honeycrisp exceeds expectations and will be recorded in the extra_productivity file.
# The product of Gala exceeds expectations and will be recorded in the extra_productivity file.
# 1. View and manage fruit categories in the orchard.
# 2. View and manage production regions in the orchard
# 3. Manage or visualize inventory of the orchard
# 4. Manage or visualize sales of the orchard
# 0. exit the system
# Please enter your choice: 1
# Fruit operations:
# 1. View fruit features
# ...

# %%
# %run main.py
# Out:
# Welcome to the Orchard Management Software, where you can easily manage your orchard, record harvests, and create a fruitful orchard experience!
#                         Ambrosia apple Elberta peach Lapins cherry
# pick_area                            0             0            40
# picking_regions_index             None          None             3
# market_area                         20            30             0
# marketing_regions_index              1             2          None
# The product of Honeycrisp exceeds expectations and will be recorded in the extra_productivity file.
# The product of Gala exceeds expectations and will be recorded in the extra_productivity file.
# 1. View and manage fruit categories in the orchard.
# 2. View and manage production regions in the orchard
# 3. Manage or visualize inventory of the orchard
# 4. Manage or visualize sales of the orchard
# 0. exit the system
# Please enter your choice: 3
# Inventory Operations:
# 1. View Current Inventory
# ...

# %%
# %run main.py
# Out:
# Welcome to the Orchard Management Software, where you can easily manage your orchard, record harvests, and create a fruitful orchard experience!
# The product of Honeycrisp exceeds expectations and will be recorded in the extra_productivity file.
# The product of Gala exceeds expectations and will be recorded in the extra_productivity file.
# 1. View and manage fruit categories in the orchard.
# 2. View and manage production regions in the orchard
# 3. Manage or visualize inventory of the orchard
# 4. Manage or visualize sales of the orchard
# 0. exit the system
# Please enter your choice: 3
# Inventory Operations:
# 1. View Current Inventory
# 2. View Remaining Productivity
# 3. Add Inventory
# 4. Remove Inventory
# 5. View production more than estimated
# 6. View the plot of inventory history data
# 0. Back to Main Menu
# Please enter operation index here: 1
#    index  Ambrosia  Gala  Honeycrisp  Lapins  Sweetheart  Skeena  Redhaven  \
# ...

# %%
# %run main.py
# Out:
# Welcome to the Orchard Management Software, where you can easily manage your orchard, record harvests, and create a fruitful orchard experience!
# The product of Honeycrisp exceeds expectations and will be recorded in the extra_productivity file.
# The product of Gala exceeds expectations and will be recorded in the extra_productivity file.
# 1. View and manage fruit categories in the orchard.
# 2. View and manage production regions in the orchard
# 3. Manage or visualize inventory of the orchard
# 4. Manage or visualize sales of the orchard
# 0. exit the system
# Please enter your choice: 4
# Sales Operations:
# 1. Add Sales Order
# 2. Add Picking Order
# 3. Display Orders
# 4. Display Revenue by Sales Type or Fruit Type
# 5. Plot Revenue Distribution by Fruit Type
# 0. Back to Main Menu
# Please enter operation index here: 1
# Enter fruit variety(choose from Ambrosia, Lapins, Elberta): Ambrosia
# Enter weight: 20
# ...
